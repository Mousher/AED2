# %% [markdown]
# ### - Exercício 1:
# #### Crie uma lista em Python chamada frutas com os seguintes elementos: "maçã", "banana", "laranja". Em seguida, adicione a fruta "morango" ao final da lista. Por fim, imprima a lista completa.

# %%
frutas = ["Maçã", "Banana", "Laranja"]

# %%
frutas.append("Morango")

# %%
print(frutas)
# Out:
# ['Maçã', 'Banana', 'Laranja', 'Morango']

# %% [markdown]
# ### Exercício 2:
# #### Crie uma pilha (usando uma lista Python) chamada livros. Adicione os livros "O Pequeno Príncipe", "Dom Quixote" e "1984" nesta ordem. Em seguida, simule a remoção do livro do topo da pilha e imprima o livro removido e a pilha restante.

# %%
livros = ["O pequeno Principe","Dom Quixoet","1985"]

# %%
livros.pop()
# Out:
# '1985'

# %%
print(livros)
# Out:
# ['O pequeno Principe', 'Dom Quixoet']

# %% [markdown]
# ### Exercício 3:
# #### Crie uma fila (usando uma lista Python) chamada clientes. Adicione os clientes "Ana", "Bruno" e "Carla" nesta ordem. Em seguida, simule a chegada de um novo cliente "Daniel" e a saída do primeiro cliente da fila. Imprima o cliente que saiu e a fila restante.

# %%
clientes = ["Ana","Bruno","Carla"]

# %%
clientes.append("Daniel")

# %%
clientes.pop(0)
# Out:
# 'Ana'

# %%
print(clientes)
# Out:
# ['Bruno', 'Carla', 'Daniel']

# %% [markdown]
# ### Exercício 4:
# #### Crie um dicionário em Python chamado contatos para armazenar o número de telefone de duas pessoas: "Ana" com o telefone "1234-5678" e "Bruno" com o telefone "9876-5432". Em seguida, adicione o contato de "Carlos" com o telefone "1122-3344". Por fim, imprima o número de telefone da Ana.

# %%
contatos = {"Ana":"1234-5678","Bruno":"9876-5432"}

# %%
contatos ["Carlos"] = "1122-3344"

# %%
print(contatos)
# Out:
# {'Ana': '1234-5678', 'Bruno': '9876-5432', 'Carlos': '1122-3344'}

# %%
print(f" Telefone Ana: {contatos["Ana"]}")
# Out:
#  Telefone Ana: 1234-5678

# %% [markdown]
# ### Projeto 1: A Agenda de Contatos:
# #### Contexto: Você precisa criar um sistema simples para armazenar e gerenciar contatos (nome, telefone e e-mail). • Problema: Como você pode adicionar novos contatos, buscar um contato pelo nome e listar todos os contatos? • Indicação de como resolver: Pensar em uma estrutura que permita associar informações (telefone e e-mail) a um nome de forma eficiente. • Resolução do Projeto 1: Um dicionário em Python é uma excelente escolha para este projeto. A chave pode ser o nome do contato, e o valor pode ser outro dicionário contendo o telefone e o e-mail.

# %%
agenda = {}

def adicionar_contato(nome, telefone, email):
    agenda[nome] = {"telefone": telefone, "email": email}
    print(f"Contato {nome} adicionado com sucesso!")

def buscar_contato(nome):
    if nome in agenda:
        info = agenda[nome]
        print(f"Nome: {nome} | Tel: {info['telefone']} | Email: {info['email']}")
    else:
        print("Contato não encontrado.")

def listar_contatos():
    print("\n--- Lista de Contatos ---")
    for nome, info in agenda.items():
        print(f"Nome: {nome} - Tel: {info['telefone']}")

adicionar_contato("Ana", "1234-5678", "ana@gmail.com")
adicionar_contato("Bruno", "9876-5432", "bruno@gmail.com")
adicionar_contato("Carlos", "1122-3344", "carlos@gCarloscom")
buscar_contato("Carlos")
listar_contatos()
# Out:
# Contato Ana adicionado com sucesso!
# Contato Bruno adicionado com sucesso!
# Contato Carlos adicionado com sucesso!
# Nome: Carlos | Tel: 1122-3344 | Email: carlos@gCarloscom
#
# --- Lista de Contatos ---
# Nome: Ana - Tel: 1234-5678
# Nome: Bruno - Tel: 9876-5432
# Nome: Carlos - Tel: 1122-3344

# %% [markdown]
# ### Projeto 2: A Lista de Tarefas:
# #### Contexto: Você precisa criar uma lista de tarefas para a semana. • Problema: Como você pode adicionar novas tarefas, marcar tarefas como concluídas e visualizar as tarefas pendentes? • Indicação de como resolver: Pensar em uma forma de manter uma sequência de itens que podem ser adicionados e removidos. • Resolução do Projeto 2: Uma lista em Python é ideal para essa situação. Podemos adicionar novas tarefas ao final da lista, remover tarefas quando concluídas e simplesmente imprimir a lista para visualizar as tarefas pendentes.

# %%
tarefas_pendentes = []

def adicionar_tarefa(tarefa):
    tarefas_pendentes.append(tarefa)
    print(f"Tarefa '{tarefa}' adicionada!")

def marcar_concluida(tarefa):
    if tarefa in tarefas_pendentes:
        tarefas_pendentes.remove(tarefa)
        print(f"Tarefa '{tarefa}' marcada como concluída e removida.")
    else:
        print("Tarefa não encontrada na lista.")

def visualizar_tarefas():
    print("\n--- Tarefas Pendentes ---")
    if not tarefas_pendentes:
        print("Nenhuma tarefa pendente.")
    for i, tarefa in enumerate(tarefas_pendentes, 1):
        print(f"{i}. {tarefa}")

adicionar_tarefa("Estudar Git e GitHub")
adicionar_tarefa("Revisar lógica proposicional")
visualizar_tarefas()
marcar_concluida("Estudar Git e GitHub")
visualizar_tarefas()
# Out:
# Tarefa 'Estudar Git e GitHub' adicionada!
# Tarefa 'Revisar lógica proposicional' adicionada!
#
# --- Tarefas Pendentes ---
# 1. Estudar Git e GitHub
# 2. Revisar lógica proposicional
# Tarefa 'Estudar Git e GitHub' marcada como concluída e removida.
#
# --- Tarefas Pendentes ---
# 1. Revisar lógica proposicional
